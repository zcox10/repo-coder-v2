# %%
# Out:
# Mounted at /content/drive

# %%
# imports
# !git clone https://github.com/zcox10/repo-coder-v2.git
# !mv /content/repo-coder-v2/* /content/

# !pip install \
    tiktoken==0.9.0 \
    transformers==4.51.3 \
    editdistance==0.8.1 \
    torch==2.6.0
# Out:
# Cloning into 'repo-coder-v2'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 150 (delta 49), reused 126 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (150/150), 481.16 KiB | 13.75 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...

# %%
import shutil
from google.colab import drive
drive.mount("/content/drive/MyDrive/learning/school/columbia/research/vector_databases/repos/repo-coder-v2/")

base = "/content/drive/MyDrive/learning/school/columbia/research/vector_databases/repos/repo-coder-v2/"
datasets_src = base + "data/datasets"
datasets_dst = "/content/data/datasets"

repos_src = base + "data/repositories"
repos_dst = "/content/data/repositories"

shutil.copytree(datasets_src, datasets_dst)
shutil.copytree(repos_src, repos_dst)
# Out:
# Mounted at /content/drive

# %%
from main import main
from src.utils.constants import Constants
import logging

# %%
logging.basicConfig(level=logging.INFO, format="\n%(levelname)s - %(message)s")

# Repositories to evaluate
repos = [
    "huggingface_diffusers",
    "nerfstudio-project_nerfstudio",
    # "awslabs_fortuna",
    # "huggingface_evaluate",
    # "google_vizier",
    # "alibaba_FederatedScope",
    # "pytorch_rl",
    # "opendilab_ACE",
]

main(
    model_name="Salesforce/codegen-350M-mono",
    benchmarks=[Constants.short_api_benchmark, Constants.short_line_benchmark],
    repos=repos,
    window_sizes=[20],
    slice_sizes=[2],
    max_top_k=10,
    vector_type="one-gram",
    max_new_tokens=100,
    batch_size=16,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/999 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/797M [00:00<?, ?B/s]
# ...
